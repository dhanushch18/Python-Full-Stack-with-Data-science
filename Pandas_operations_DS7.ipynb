# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushch18/Python-Full-Stack-with-Data-science/blob/main/Pandas_operations_DS7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operations

# %%
import pandas as pd
df=pd.DataFrame({'col1':[1,2,3,4],'col2':[555,777,666,777],'col3':['a','b','c','d']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   555    a
# 1     2   777    b
# 2     3   666    c
# 3     4   777    d

# %%
df['col2'].unique()
# Out:
# array([555, 777, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 777    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
#Selecting Data
#Select from DataFrame using criteria from multiple columns
newdf = df[(df['col1']>2) & (df['col2']==777)]

# %%
newdf
# Out:
#    col1  col2 col3
# 3     4   777    d

# %% [markdown]
# Applying Functions

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# Name: col3, dtype: int64

# %%
df['col1'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64>

# %%
del df['col1']
df
# Out:
#    col2 col3
# 0   555    a
# 1   777    b
# 2   666    c
# 3   777    d

# %%
df.columns
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df
# Out:
#    col2 col3
# 0   555    a
# 1   777    b
# 2   666    c
# 3   777    d

# %%
df.sort_values(by='col2') #inplace=False by default
# Out:
#    col2 col3
# 0   555    a
# 2   666    c
# 1   777    b
# 3   777    d

# %% [markdown]
# ** Find Null Values or Check for Null Values**

# %%
df.isnull()
# Out:
#     col2   col3
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
df.dropna()
# Out:
#    col2 col3
# 0   555    a
# 1   777    b
# 2   666    c
# 3   777    d

# %% [markdown]
# ** Filling in NaN values with something else: **

# %%
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna('Fill')
# Out:
#    col1   col2 col3
# 0   1.0   Fill  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3  Fill  444.0  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %% [markdown]
# Great Job..!
